# %%
import pandas as pd
df = pd.read_csv('/content/index_1.csv')

# %%
df.head(10)
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
# 5  2024-03-01  2024-03-01 15:39:47.726      card  ANON-0000-0000-0005   33.8
# 6  2024-03-01  2024-03-01 16:19:02.756      card  ANON-0000-0000-0006   38.7
# 7  2024-03-01  2024-03-01 18:39:03.580      card  ANON-0000-0000-0007   33.8
# 8  2024-03-01  2024-03-01 19:22:01.762      card  ANON-0000-0000-0008   38.7
# 9  2024-03-01  2024-03-01 19:23:15.887      card  ANON-0000-0000-0008   33.8
#
#            coffee_name
# 0                Latte
# 1        Hot Chocolate
# 2        Hot Chocolate
# 3            Americano
# ...

# %%
df.tail(10)
# Out:
#             date                 datetime cash_type                 card  \
# 3626  2025-03-22  2025-03-22 15:57:58.183      card  ANON-0000-0000-1302
# 3627  2025-03-22  2025-03-22 16:26:59.766      card  ANON-0000-0000-1274
# 3628  2025-03-22  2025-03-22 17:53:35.942      card  ANON-0000-0000-1274
# 3629  2025-03-22  2025-03-22 19:16:52.727      card  ANON-0000-0000-1314
# 3630  2025-03-23  2025-03-23 10:07:11.278      card  ANON-0000-0000-1196
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money          coffee_name
# 3626  21.06             Espresso
# 3627  35.76                Latte
# 3628  30.86  Americano with Milk
# ...

# %%
df.shape
# Out:
# (3636, 6)

# %%
df.columns
# Out:
# Index(['date', 'datetime', 'cash_type', 'card', 'money', 'coffee_name'], dtype='object')

# %%
df.dtypes
# Out:
# date            object
# datetime        object
# cash_type       object
# card            object
# money          float64
# coffee_name     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['coffee_name'].unique()
# Out:
# array(['Latte', 'Hot Chocolate', 'Americano', 'Americano with Milk',
#        'Cocoa', 'Cortado', 'Espresso', 'Cappuccino'], dtype=object)

# %%
sold = df['coffee_name'].value_counts()
sold
# Out:
# coffee_name
# Americano with Milk    824
# Latte                  782
# Americano              578
# Cappuccino             501
# Cortado                292
# Hot Chocolate          282
# Cocoa                  243
# Espresso               134
# Name: count, dtype: int64

# %%
sold.idxmax()
# Out:
# 'Americano with Milk'

# %%
sold.idxmin()
# Out:
# 'Espresso'

# %%
df['money'].sum()
# Out:
# np.float64(115431.58)

# %%
df['money'].mean()
# Out:
# np.float64(31.74685918591859)

# %%
df['money'].min()
# Out:
# 18.12

# %%
df['money'].max()
# Out:
# 40.0

# %%
df['money'].std()
# Out:
# 4.919925803555333

# %%
df[df['money']> 35]
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# 6     2024-03-01  2024-03-01 16:19:02.756      card  ANON-0000-0000-0006
# ...          ...                      ...       ...                  ...
# 3630  2025-03-23  2025-03-23 10:07:11.278      card  ANON-0000-0000-1196
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money    coffee_name
# 0     38.70          Latte
# 1     38.70  Hot Chocolate
# ...

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df['month'] = df['datetime'].dt.month
df['hour'] = df['datetime'].dt.hour

# %%
df.groupby(['month','coffee_name'])['money'].sum()
# Out:
# month  coffee_name
# 1      Americano               649.00
#        Americano with Milk    1604.72
#        Cappuccino              965.52
#        Cocoa                   500.64
#        Cortado                 571.12
#                                ...
# 12     Cocoa                   750.96
#        Cortado                 804.76
#        Espresso                252.72
#        Hot Chocolate           929.76
#        Latte                  1680.72
# Name: money, Length: 96, dtype: float64

# %%
df['hour'].value_counts().idxmax()
# Out:
# np.int32(10)

# %%
df.groupby('month')['money'].sum().idxmax()
# Out:
# np.int32(3)
